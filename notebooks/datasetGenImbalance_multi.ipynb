# %% [markdown]
# ### This notebook specifially focuses on generating additional data for **MULTI ROOM** control.
# #### Why? To address the imbalance in dataset where multi room control commands were way lesser in quantity and many rooms were not addressed.

# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from typing import List, Dict
import random
import shutil

import sys
sys.path.append('../scripts')  

from jsontocsv import update_csv_from_json

# %%
load_dotenv()
# Configure OpenAI API key
openai = OpenAI()
api_key = os.getenv("OPENAI_API_KEY")

# %%
system = '''You are an assistant trained to generate Nepali-English code-mixed smart home control commands for fine-tuning a language model. 
Your task is to follow the updated guidelines and create commands as provided in the examples.'''

# %%
user = '''1. Guideline for Commands:
   - Commands should be **Nepali-English code-mixed**, with some in **full English** and **Nepali-dominant**, but written in **Romanized Nepali** (transliterated Nepali to English):
     - **50% Code-Mixed:** e.g., "bardali ko batti balnu" or "balcony lights dim gara".
     - **30% Fully English:** e.g., "Turn off the lights in the store room and terrace."
     - **20% Nepali-Dominant (Transliterated):** e.g., "Kausi ra dining area ko batti balera rakhnus."
   - **Do not** generate commands in fully native Nepali script (e.g., "भान्सा" or "किचन"). Use Romanized Nepali instead.
   - Incorporate natural variations in grammar, phrasing, and spelling.
   - Commands may include requests or polite phrasing. For instance:
     - Store room ra terrace ko batti off garna milcha?
     - Can you brighten the dining area and corridor lights?

2. Room Names:
   - Generate commands for the following rooms:
     - **Store Room**: `store`, `store room`.
     - **Bathroom**: `bathroom`, `snaan kotha`.
     - **Terrace**: `kausi`, `chat`, `chhat`.
     - **Corridor**: `baato`, `bato`.
     - **Dining Area**: `dining`, `dining area`, `khaana kotha`.
     - **Prayer Room**: `puja kotha`, `mandir`.

3. Intent:
   - Generate commands exclusively for **multi_room_control** intent.
   - Each command should involve two rooms.
   - Example: "Turn off the lights in the store room and kausi."

4. JSON Output Requirements:
   - Translate Nepali transliterations to English room names in the `actions` section.
   - Follow this consistent JSON structure:
     {
      "command": "<natural language command>",
      "intent": "multi_room_control",
      "rooms": [
          "<list_of_room_names>"
      ],
      "actions": [
          {
              "room": "<room_name>",
              "action": "<turn_on | turn_off | adjust_brightness | change_color>",
              "brightness": "<optional: 0 to 1>",
              "color": "<optional: red | blue | green | etc.>"
          }
      ]
    }

5. Examples:
   - **Code-Mixed:** 
     ```json
     {
       "command": "Store room ra terrace ko batti off garnus.",
       "intent": "multi_room_control",
       "rooms": ["store room", "terrace"],
       "actions": [
           {
               "room": "store room",
               "action": "turn_off"
           },
           {
               "room": "terrace",
               "action": "turn_off"
           }
       ]
     }
     ```
   - **Fully English:**
     ```json
     {
       "command": "Turn off the lights in the corridor and dining area.",
       "intent": "multi_room_control",
       "rooms": ["corridor", "dining area"],
       "actions": [
           {
               "room": "corridor",
               "action": "turn_off"
           },
           {
               "room": "dining area",
               "action": "turn_off"
           }
       ]
     }
     ```

6. Generate Variations:
   - Generate 30 commands as an array of JSON objects following these guidelines, ensuring diversity and natural phrasing.
   - Include all listed rooms across commands.'''

# %%
def builder(system, user):
    return [{"role":"system", "content":system},
            {"role":"user", "content":user}
           ]

# %%
# combining all the steps
def generate_dataset(system, user):
    try:
        response = openai.chat.completions.create(model = "gpt-4o",
                                                  messages = builder(system, user),
                                                  temperature = 0.8, 
                                                  # max_tokens = 2000,
                                                #   response_format={"type": "json_object"}
                                                  )
        # dataset = json.loads(response.choices[0].message.content)
        dataset = (response.choices[0].message.content)
        return dataset
    except Exception as e:
        print(f"Error generating dataset: {str(e)}")
        return []

# %%
# function to save the dataset as json      
def save_dataset(dataset: List[Dict], filename: str):
    """Save the generated dataset to a JSON file"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(dataset, f, ensure_ascii=False, indent=4)

# %%
def tojsonDump():
    root_path = "../data/jsonRawAdditionalMulti"
    try:
        # Ensure the directory exists
        os.makedirs(root_path, exist_ok=True)
        
        if len(os.listdir(root_path)) == 0:
            shutil.copy("light_automation_dataset.json", "light_automation_dataset_1.json")
            shutil.move("light_automation_dataset_1.json", root_path)
        else:
            num = len(os.listdir(root_path)) + 1
            fname = "light_automation_dataset_" + f"{num}" + ".json"
            shutil.copy("light_automation_dataset.json", fname)
            shutil.move(fname, root_path)
        print("Moved successfully to jsonDump. File: ", fname)
    except Exception as e:
        print(f"Error moving to {root_path}", str(e))

# %%
if __name__ == "__main__":
    dataset = generate_dataset(system, user)
    
    if dataset:
        #Save the dataset
        dataset1 = dataset[7:]
        dataset1 = dataset1[:-3]
        dataset1 = json.loads(dataset1)
        save_dataset(dataset1, "light_automation_dataset.json")
        print(f"Successfully generated and saved {len(dataset1)} samples to light_automation_dataset.json")
        tojsonDump()
        # update_csv_from_json("light_automation_dataset.json", "annotator_data.csv")
    else:
        print("Failed to generate dataset")
# Out:
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_137.json

# %%
# for i in range(80):
#     print("Itr: ", i+1)
#     dataset = generate_dataset(system, user)
    
#     if dataset:
#         #Save the dataset
#         dataset1 = dataset[7:]
#         dataset1 = dataset1[:-3]
#         dataset1 = json.loads(dataset1)
#         save_dataset(dataset1, "light_automation_dataset.json")
#         print(f"Successfully generated and saved {len(dataset1)} samples to light_automation_dataset.json")
#         tojsonDump()
#         # update_csv_from_json("light_automation_dataset.json", "annotator_data.csv")
#     else:
#         print("Failed to generate dataset")
# Out:
# Itr:  1
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_57.json
# Itr:  2
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_58.json
# Itr:  3
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_59.json
# Itr:  4
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_60.json
# Itr:  5
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_61.json
# Itr:  6
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_62.json
# Itr:  7
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_63.json
# Itr:  8
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_64.json
# Itr:  9
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_65.json
# Itr:  10
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_66.json
# Itr:  11
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_67.json
# Itr:  12
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_68.json
# Itr:  13
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_69.json
# Itr:  14
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_70.json
# Itr:  15
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_71.json
# Itr:  16
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_72.json
# Itr:  17
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_73.json
# Itr:  18
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_74.json
# Itr:  19
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_75.json
# Itr:  20
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_76.json
# Itr:  21
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_77.json
# Itr:  22
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_78.json
# Itr:  23
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_79.json
# Itr:  24
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_80.json
# Itr:  25
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_81.json
# Itr:  26
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_82.json
# Itr:  27
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_83.json
# Itr:  28
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_84.json
# Itr:  29
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_85.json
# Itr:  30
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_86.json
# Itr:  31
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_87.json
# Itr:  32
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_88.json
# Itr:  33
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_89.json
# Itr:  34
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_90.json
# Itr:  35
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_91.json
# Itr:  36
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_92.json
# Itr:  37
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_93.json
# Itr:  38
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_94.json
# Itr:  39
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_95.json
# Itr:  40
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_96.json
# Itr:  41
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_97.json
# Itr:  42
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_98.json
# Itr:  43
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_99.json
# Itr:  44
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_100.json
# Itr:  45
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_101.json
# Itr:  46
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_102.json
# Itr:  47
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_103.json
# Itr:  48
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_104.json
# Itr:  49
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_105.json
# Itr:  50
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_106.json
# Itr:  51
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_107.json
# Itr:  52
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_108.json
# Itr:  53
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_109.json
# Itr:  54
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_110.json
# Itr:  55
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_111.json
# Itr:  56
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_112.json
# Itr:  57
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_113.json
# Itr:  58
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_114.json
# Itr:  59
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_115.json
# Itr:  60
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_116.json
# Itr:  61
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_117.json
# Itr:  62
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_118.json
# Itr:  63
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_119.json
# Itr:  64
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_120.json
# Itr:  65
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_121.json
# Itr:  66
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_122.json
# Itr:  67
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_123.json
# Itr:  68
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_124.json
# Itr:  69
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_125.json
# Itr:  70
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_126.json
# Itr:  71
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_127.json
# Itr:  72
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_128.json
# Itr:  73
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_129.json
# Itr:  74
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_130.json
# Itr:  75
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_131.json
# Itr:  76
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_132.json
# Itr:  77
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_133.json
# Itr:  78
# Successfully generated and saved 30 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_134.json
# Itr:  79
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_135.json
# Itr:  80
# Successfully generated and saved 29 samples to light_automation_dataset.json
# Moved successfully to jsonDump. File:  light_automation_dataset_136.json

# %% [markdown]
# **16** minutes for 600 rows of data.
# **30** minutes for approx. 1000 rows of data.
# **67** minutes for approx. 2400 rows of data.

# %%
## 4000 total needed
import json
root = "../data/jsonRawAdditionalMulti"
length = 0
for file in (os.listdir(root)):
    fullpath = os.path.join(root, file)
    # print(fullpath)
    with open(fullpath, 'r') as jsonFile:
        f = json.load(jsonFile)
    length += len(f)
print(length)
print(4000-length, " more needed.")
# Out:
# 4010
# -10  more needed.
